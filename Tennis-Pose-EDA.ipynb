# %% [markdown]
# Objective: Determine what position the tennis player in the image is in
#
# Poses: backhand, forehand, ready_position, serve
#
# Size: 2000 images, 500 for each pose
#
# Fomrat: Images in .jpeg format and annotations in COCO-format .json
#
# Key data points: ["nose", "left_eye", "right_eye", "left_ear", "right_ear", "left_shoulder", "right_shoulder", "left_elbow", "right_elbow", "left_wrist", "right_wrist", "left_hip", "right_hip", "left_knee", "right_knee", "left_ankle", "right_ankle", "neck"]

# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import numpy as np

data_path = '/kaggle/input/tennis-player-actions-dataset'
annotations_path = os.path.join(data_path, 'annotations')
images_path = os.path.join(data_path, 'images')

# with open(os.path.join(annotations_path, 'serve.json'), 'r') as f:
#   serve_data = json.load(f)

# print(f"Keys in COCO JSON: {serve_data.keys()}")

# %% [markdown]
# Since there are 500 images for each pose, the datset is balanced and there are no class imbalance issues. We will have to use the coordinates of key points to find out where the player is positioned in the image. This can be done with a heatmap.
